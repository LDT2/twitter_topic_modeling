# %%
import pandas as pd
import numpy as np
import random
import math
import preprocessor as p
from nltk.corpus import stopwords
import nltk
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
import string
import spacy
import es_core_news_sm
import re
from pprint import pprint

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# %%
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# ## Import Data

# %%
from import_data import read_data

# %%
data = read_data('../data', 2016, 2016, 1)
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data1_cleaned["tweet_time"] = pd.to_datetime(data1_cleaned["tweet_time"])
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data1_cleaned['year'] = data1_cleaned.index.year
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data1_cleaned['month'] = data1_cleaned.index.month
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data2_cleaned["tweet_time"] = pd.to_datetime(data2_cleaned["tweet_time"])
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data2_cleaned['year'] = data2_cleaned.index.year
# /Users/lthomas/Dropbox/galvanize/Capstone/notebooks/import_data.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data2_cleaned['month'] = data2_cleaned.index.month

# %% [markdown]
# ## Filter Out RTs

# %%
unique_data = data[data.is_retweet == False]

# %% [markdown]
# ## Create Quarterly Datasets (optional)

# %%
# running analysis on all 2016 data

# %% [markdown]
# ## Group by UserID

# %%
def create_user_docs(tweets_vec):
    return " ".join([tweet for tweet in tweets_vec ])

# %%
docs = unique_data.groupby('userid')

# %%
df_tweets = docs['tweet_text'].apply(create_user_docs)

# %% [markdown]
# ### Filter out users with tweets less than 10 words

# %%
tweet_len = pd.Series(df_tweets).apply(lambda x:  len(x.split()))

# %%
df_tweets = df_tweets[ tweet_len > 10 ]

# %%
data_list = df_tweets.values.tolist()
print(data_list[0])
# Out:
# Una cadena es tan fuerte como su eslabón más frágil. El peor error que alguien puede cometer es creerle a un político. Que beta, yo pensé que estábamos comenzando el mes de Julio. Sueño ven a mi. Khe https://t.co/5G6GnCo7Mt Buen día a todos los que leen esto. El que no está no hace falta. Cuando tenga otros perros los llamaría 'Delta' y 'Tomahowk'. Feliz cumpleaños mi amorsote💜💜 @HeeyDane Voy con calma y sin apuro porque no me gusta estar gastando pólvora en zamuros. El que no tiene argumento insulta y responde con preguntas. Este país necesita personas profesionales, no solo a nivel laboral sino a nivel personal. En este momento desearía estar en la orilla de la playa con unas cervezas. Todo lo que hagas importa. Nacidos para correr bebe. Todos los sábados de mi vida: https://t.co/ZkkMA3VtxT Kriss Kyle😍😍😍 https://t.co/TrvOk0PbF4 Que no duren momentos duros. El gallo no pone. https://t.co/BOl4EjbrXG Lo peligroso de un perdedor es que no tiene nada que perder. “Mas que su sonrisa, analicen la mirada de una persona.” Feliz año lacras. Deseo mucho dinero. Esteros y morichales. Lento camino hacia ninguna parte. Nunca es tarde para cambiar. Es ahora o nunca, si quieres pescar grandes peces tienes que ir a aguas profundas. La historia de mi vida. https://t.co/WKtskri4Fz Me gustan mucho las mujeres con lentes. @KarlosGodoy3 Que marico ese muchacho. En sus temas hablan de millones y kilos, pero andan a pie con el currículum en un sobre manila bajo la axila. Y que reales que por un pique y riales se alteran. Lento pero seguro, sin apuro. No es que me las sepa todas, es que desconocen verdades ocultas. Si la melancolía no existiera los colibrí se pondrían a eructar. https://t.co/pd3telD7v1 Que bonita esa nueva asamblea. Fuego helado. Nunca en tu vida esperes algo de alguien. Que ladilla desarm
https://t.co/1UPGQfbkW6 Lo malo de admirar es mirar como te acomplejas. Me gustan esas conversaciones con ella. El rap queda mientras pasan los que rapean. Nadie vio tu cabello. https://t.co/o8ww0g1WeV Uno sale y no sabe si vuelve. Que lacra esa carajita. Lo peligroso de un perdedor es que no tiene nada que perder. Deorro - I Can Be Somebody. Las canciones "panda" son malas, pero la pista suena brrrutaaall. No le eches la culpa a ese señor. https://t.co/tNBELr5XMo Y tu cada día mas buena. https://t.co/Tj0KnQ145N Rap Caribe. Momentos de rebelión. El remordimiento es mas grande que la gratitud. Daneska odia mucho a esa chama😂😂😂😂 Tendré poco, pero lo poco que tengo me lo he ganado. Estaremos bien, porque somos Nathan James. Vieras quien se llena con el vacío de otros. S💜 Ya veoo https://t.co/tUO3oEBoaD Noctámbulo y con cara de culo deambulo. No es lo alto que llegues, lo que importa es la manera. Que noche. Las emociones no se miden, el éxito si. Sabias palabras. https://t.co/dzGrIN7Nvl I can be somebody. Hago lo que critico. Por los cuentos que la luna relata aprendí a caminar sin mapa. Ya es un lujo tener lo necesario. Y como no hay nada para hoy veré piratas del caribe. Ayer andábamos en 140 y en 4ta, cuando metimos 5ta se acabo la autopista:( Tan inocente que se veía. @YuliannyAlbujar Que rata, no me pudiste guardar uno Stole the show. https://t.co/788kavwbXl Que rico suena la bicicleta cuando cae. Que tetas tan lindas😊😊 https://t.co/lD5srTms4N Si estamos aquí es por algún motivo. El publico tonto solo se anima cuando oye una grosería. @LuisanaaV Si va. Todos creen estar al mando si ven el sartén sin mango. Que triste. No perjudiques a los que tienes al lado y te tratan con respeto. Donde golpean muy fuerte al que nunca hace caso. De lo que en mi época llamaban 'represent' ha llegado este tren. El mundito del rap. En el camino que desempeñes no la sueñes. Que bien que no fumo. https://t.co/9DxYqxwoLA Amplia tus conocimientos, ponte a leer aunque sea cuentos. No me gusta ese juego. https://t.co/uOlYN7fPHf La niñez se disfruta sin tecnología. Amigos, la droga hace daño. https://t.co/XY6H79HcZP Las mujeres con zapatos Nike se ven muy bien. Amor &amp; odio. Cada vez que lo recuerdo  ...

# %% [markdown]
# ## Text Preprocessing Pipeline

# %% [markdown]
# ### Define functions for processing

# %%
def remove_url_emojis(tweets):
    '''
    input: tweets is a list of strings (untokenized)
    output: list of strings (untokenized)
    '''
    p.set_options(p.OPT.EMOJI, p.OPT.URL, p.OPT.RESERVED, p.OPT.NUMBER)
    
    return [ p.clean(tweet) for tweet in tweets ]

# %%
def tweet_to_tokens(tweets):
    return [ [token.lower() for token in tweet.split()
                 if (len(token) >= 3) and (len(token) <= 15)] for tweet in tweets]

# %%
def remove_symbols(tweets):
    '''
    input: tweets is a list of list of tokens
    output: list of list of tokens
    '''
    symbol_set = set('!"$%&\'()*,-./:;<>?[\\]^_`{|}~¿… °¡')
    
    return [[''.join(char for char in token if char not in symbol_set) 
              for token in tweet] 
                for tweet in tweets]

# %%
def remove_accents(tweets):
    def accent_check(char):
        accents = set('áéíóñ')
        if char not in accents:
            return char
        elif char == 'á':
            return 'a'
        elif char == 'é':
            return 'e'
        elif char == 'í':
            return 'i'
        elif char == 'ó':
            return 'o'
        elif char == 'ú':
            return 'u'
        elif char == 'ñ':
            return 'n'
    
    return [[ ''.join(accent_check(char) for char in token) 
                for token in tweet]
                    for tweet in tweets]

# %%
def remove_stopwords(tweets):
    '''
    input: tweets is a list of list of tokens
    output: list of list of cleaner tokens
    '''

    # NLTK Stop words
    stop_words_es = stopwords.words('spanish')
    stop_words_en = stopwords.words('english')
    stop_words = stop_words_es + stop_words_en
    stop_words.extend(['lol', 'LOL', 'Lol', 'LoL', 'jaja', 'jajaj'])

    return [[token for token in tweet 
                     if token not in stop_words] 
                        for tweet in tweets]

# %%
# def remove_laughing(tweets):
#     # remove laughter
#     matcher = re.compile(r'(ja)\1*')
#     return [[token for token in tweet
#                     if token not in [match.group() for match in matcher.finditer(' '.join(tweet))]]
#                         for tweet in tweets]

# %%
def make_bigrams(tweets):
    return [bigram_mod[tweet] for tweet in tweets]

# %%
def make_trigrams(tweets):
    return [trigram_mod[bigram_mod[tweet]] for tweet in tweets]

# %%
def lemmatization(tweets, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    # Lemmatize and rejoin
    
    #nlp = es_core_news_sm.load()
    tweets_out = []
    for tweet in tweets:
        doc = nlp(" ".join(tweet)) 
        tweets_out.append([token.lemma_ for token in doc 
                           if token.pos_ in allowed_postags])
    return tweets_out

# %% [markdown]
# ### Remove URLS and Emojis

# %%
data_no_entities = remove_url_emojis(data_list)

# %% [markdown]
# ### Tokenize tweets

# %%
data_tokens = tweet_to_tokens(data_no_entities)

# %%
data_tokens[0]
# Out:
# ['una',
#  'cadena',
#  'tan',
#  'fuerte',
#  'como',
#  'eslabón',
#  'más',
#  'frágil.',
#  'peor',
#  'error',
#  'que',
#  'alguien',
#  'puede',
#  'cometer',
#  'creerle',
#  'político.',
#  'que',
#  'beta,',
#  'pensé',
#  'que',
#  'estábamos',
#  'comenzando',
#  'mes',
#  'julio.',
#  'sueño',
#  'ven',
#  'mi.',
#  'khe',
#  'buen',
#  'día',
#  'todos',
#  'los',
#  'que',
#  'leen',
#  'esto.',
#  'que',
#  'está',
#  'hace',
#  'falta.',
#  'cuando',
#  'tenga',
#  'otros',
#  'perros',
#  'los',
#  'llamaría',
#  "'delta'",
#  "'tomahowk'.",
#  'feliz',
#  'cumpleaños',
#  'amorsote',
#  '@heeydane',
#  'voy',
#  'con',
#  'calma',
#  'sin',
#  'apuro',
#  'porque',
#  'gusta',
#  'estar',
#  'gastando',
#  'pólvora',
#  'zamuros.',
#  'que',
#  'tiene',
#  'argumento',
#  'insulta',
#  'responde',
#  'con',
#  'preguntas.',
#  'este',
#  'país',
#  'necesita',
#  'personas',
#  'profesionales,',
#  'solo',
#  'nivel',
#  'laboral',
#  'sino',
#  'nivel',
#  'personal.',
#  'este',
#  'momento',
#  'desearía',
#  'estar',
#  'orilla',
#  'playa',
#  'con',
#  'unas',
#  'cervezas.',
#  'todo',
#  'que',
#  'hagas',
#  'importa.',
#  'nacidos',
#  'para',
#  'correr',
#  'bebe.',
#  'todos',
#  'los',
#  'sábados',
#  'vida:',
#  'kriss',
#  'kyle',
#  'que',
#  'duren',
#  'momentos',
#  'duros.',
#  'gallo',
#  'pone.',
#  'peligroso',
#  'perdedor',
#  'que',
#  'tiene',
#  'nada',
#  'que',
#  'perder.',
#  '“mas',
#  'que',
#  'sonrisa,',
#  'analicen',
#  'mirada',
#  'una',
#  'persona.”',
#  'feliz',
#  'año',
#  'lacras.',
#  'deseo',
#  'mucho',
#  'dinero.',
#  'esteros',
#  'morichales.',
#  'lento',
#  'camino',
#  'hacia',
#  'ninguna',
#  'parte.',
#  'nunca',
#  'tarde',
#  'para',
#  'cambiar.',
#  'ahora',
#  'nunca,',
#  'quieres',
#  'pescar',
#  'grandes',
#  'peces',
#  'tienes',
#  'que',
#  'aguas',
#  'profundas.',
#  'historia',
#  'vida.',
#  'gustan',
#  'mucho',
#  'las',
#  'mujeres',
#  'con',
#  'lentes.',
#  '@karlosgodoy3',
#  'que',
#  'marico',
#  'ese',
#  'muchacho.',
#  'sus',
#  'temas',
#  'hablan',
#  'millones',
#  'kilos,',
#  'pero',
#  'andan',
#  'pie',
#  'con',
#  'currículum',
#  'sobre',
#  'manila',
#  'bajo',
#  'axila.',
#  'que',
#  'reales',
#  'que',
#  'por',
#  'pique',
#  'riales',
#  'alteran.',
#  'lento',
#  'pero',
#  'seguro,',
#  'sin',
#  'apuro.',
#  'que',
#  'las',
#  'sepa',
#  'todas,',
#  'que',
#  'desconocen',
#  'verdades',
#  'ocultas.',
#  'melancolía',
#  'existiera',
#  'los',
#  'colibrí',
#  'pondrían',
#  'eructar.',
#  'que',
#  'bonita',
#  'esa',
#  'nueva',
#  'asamblea.',
#  'fuego',
#  'helado.',
#  'nunca',
#  'vida',
#  'esperes',
#  'algo',
#  'alguien.',
#  'que',
#  'ladilla',
#  'desarmar',
#  'ver',
#  'que',
#  'tienes',
#  'repuesto',
#  'equivocado.',
#  'sabado.',
#  'soy',
#  'propia',
#  'piedra',
#  'zapato.',
#  'hay',
#  'muro,',
#  'hay',
#  'barrera,',
#  'hay',
#  'muralla.',
#  'cosas',
#  'que',
#  'solo',
#  'sucederán',
#  'las',
#  'haces',
#  'mismo.',
#  'usted',
#  'sabe',
#  'que',
#  'quiere',
#  'esta',
#  'jodido,',
#  'porque',
#  'nada',
#  'bien',
#  'nadar',
#  'por',
#  'vida',
#  'confundido.',
#  'debí',
#  'enviar',
#  'eso.',
#  'gusta',
#  'reparar',
#  'mejorar',
#  'las',
#  'cosas.',
#  'estos',
#  'momentos.',
#  'quiero',
#  'beber',
#  'día',
#  'con',
#  'daneska.',
#  'aplomo.',
#  'largo',
#  'esta',
#  'shit.',
#  'mmmmmmm.',
#  'linten',
#  'the',
#  'warrior,',
#  'aquí',
#  'somos',
#  'varios',
#  'crew.',
#  'necesito',
#  'tirar.',
#  'elettra',
#  'lamborghini,',
#  'lindo',
#  'nombre.',
#  'efectos',
#  'hidrófonos.',
#  'puede*',
#  'gusta',
#  'hablar',
#  'tiempo',
#  'que',
#  'llevo',
#  'estudiando,',
#  'prefiero',
#  'hablar',
#  'que',
#  'falta',
#  'por',
#  'aprender.',
#  'rap',
#  'amazónico,',
#  'anti',
#  'farándula,',
#  'pedagógico,',
#  'anti',
#  'dramático',
#  'con',
#  'sentido',
#  'lógico.',
#  'distancia',
#  'beta.',
#  'bale',
#  'berga',
#  'bida.',
#  'listo',
#  'para',
#  'recibir',
#  'después',
#  'hacer',
#  'mal.',
#  'pan',
#  'con',
#  'diablito',
#  'salsa',
#  'comida',
#  'dioses.',
#  '¡amen!',
#  'horario',
#  'muy',
#  'bipolar,',
#  'los',
#  'lunes',
#  'entro',
#  'las',
#  'los',
#  'martes',
#  'las',
#  'luego',
#  'los',
#  'miércoles',
#  'las',
#  'postea',
#  'también',
#  'las',
#  'oriana.',
#  'hola',
#  'vale',
#  'trabaja',
#  'silencio.',
#  'llama',
#  'atención',
#  'donde',
#  'pisa.',
#  'digitel',
#  'sube',
#  'los',
#  'planes',
#  'tengo',
#  'señal,',
#  'que',
#  'maravilla.',
#  'culmino',
#  'semana',
#  'vacaciones.',
#  'seria',
#  'depinga',
#  'trabajar',
#  'rocket',
#  'bunny',
#  'liberty',
#  'walk.',
#  'colega,',
#  'acá',
#  'venezuela',
#  'que',
#  'vende',
#  'paraguas',
#  'mismo',
#  'que',
#  'hace',
#  'que',
#  'llueva.',
#  'tengo',
#  'quien.',
#  'llegar',
#  'arriba',
#  'fácil,',
#  'difícil',
#  'mantenerse.',
#  'hoy',
#  'andaba',
#  'con',
#  'gocho,',
#  'par',
#  'despechados',
#  'exprimo',
#  'las',
#  'canciones',
#  'buenos',
#  'cantautores.',
#  'vacilen',
#  'ignoren.',
#  'que',
#  'duren',
#  'momentos',
#  'duros.',
#  'buenos',
#  'días,',
#  'seguiré',
#  'durmiendo.',
#  'preguntamos',
#  'cómo,',
#  'cuando',
#  'como.',
#  'justicia',
#  'muda',
#  'deambula',
#  'mula',
#  'por',
#  'ahí',
#  'compae.',
#  'cuento',
#  'conmigo',
#  'mismo,',
#  'voy',
#  'paso',
#  'llano.',
#  'esperanza',
#  'error.',
#  'unos',
#  'roban',
#  'otros',
#  'luchan',
#  'para',
#  'poder',
#  'vivir.',
#  'todos',
#  'hablan',
#  'futbol',
#  'quedo',
#  'igual',
#  'que',
#  'clases',
#  'matemáticas.',
#  'día',
#  'andaba',
#  'con',
#  'mis',
#  'panas',
#  'buscamos',
#  'pique',
#  'una',
#  'tundra,',
#  'nos',
#  'dejo',
#  'fue',
#  'botados',
#  'cuerrrpo',
#  'cobaarrrde,',
#  'como',
#  'meneaas,',
#  'cargo',
#  'una',
#  'peaaa',
#  'que',
#  'dios',
#  'guaaarrrrde.',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer.',
#  'vida',
#  'una',
#  'pretenciosa',
#  'mientras',
#  'mas',
#  'bella',
#  'flor',
#  'mas',
#  'espinosa.',
#  'miedo',
#  'mas',
#  'grande',
#  'que',
#  'adversario.',
#  'los',
#  'verdaderos',
#  'guerreros',
#  'caminan',
#  'senderos',
#  'solos',
#  'con',
#  'aplomo.',
#  'todo',
#  'que',
#  'mira',
#  'termina',
#  'paranoico.',
#  'ahora',
#  'hay',
#  'pocos',
#  'talleres',
#  'venezuela',
#  'con',
#  'esas',
#  'maquinas.',
#  'nada',
#  'imposible',
#  'tienes',
#  'valor,',
#  'coraje',
#  'buen',
#  'plan.',
#  'deja',
#  'tus',
#  'miedos',
#  'atras.',
#  'termofluidos',
#  'enreda',
#  'burda.',
#  'rompe',
#  'las',
#  'cadenas',
#  'que',
#  'atan',
#  'tanta',
#  'escoria.',
#  'sobrados,',
#  'sobrando',
#  'todo.',
#  'los',
#  'que',
#  'vive',
#  'rap',
#  'real,',
#  'rap',
#  'del',
#  'bueno',
#  'del',
#  'caribe.',
#  'hermosa',
#  'con',
#  'sus',
#  'pecas',
#  'lunares.',
#  'hoy',
#  'palio',
#  'gtr',
#  'como',
#  'venga.',
#  'necesito',
#  'sexo.',
#  'esa',
#  'camioneta',
#  'perfecta',
#  'necesito',
#  'cuadre.',
#  '@jmesza',
#  'los',
#  'san',
#  'felipe',
#  'son',
#  'maricos.',
#  'dicen',
#  'verdades',
#  'caen',
#  'lona.',
#  'ainsss,',
#  'tan',
#  'bello',
#  'lucho',
#  'por',
#  'sonrisa',
#  'madre',
#  'que',
#  'vale',
#  'millón.',
#  'fue',
#  'culpa',
#  'fue',
#  'mía,',
#  'fue',
#  'destino',
#  'fue',
#  'vida.',
#  'puedo',
#  'andar',
#  'sin',
#  'bolívar',
#  'bolsillo,',
#  'pero',
#  'tranquilo',
#  'porque',
#  'soy',
#  'sencillo.',
#  'malo',
#  'mentir.',
#  'otra',
#  'noche',
#  'como',
#  'sábado.',
#  '@somos412',
#  'buen',
#  'día,',
#  'informo',
#  'que',
#  'puerto',
#  'cabello,',
#  'específicamente',
#  'borburata',
#  'hay',
#  'servicio,',
#  'esperamos',
#  'pronta',
#  'solución.',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer.',
#  'malpario',
#  'dolor',
#  'cabeza.',
#  'sencillo,',
#  'práctico,',
#  'natural.',
#  'que',
#  'soy',
#  'buen',
#  'dj.',
#  'paso',
#  'todo',
#  'día',
#  'pensando',
#  'hacer',
#  'tarea',
#  'final',
#  'hago',
#  'coño.',
#  'traes',
#  'comida',
#  'algo',
#  'para',
#  'beber',
#  'hay',
#  'peo',
#  'carcajadas',
#  'retumban.',
#  'pasa.',
#  'pierdes',
#  'nada',
#  'ganas',
#  'mucho',
#  'decirlas.',
#  'que',
#  'buen',
#  'día.',
#  'alcohol',
#  'para',
#  'todo.',
#  'iutpc',
#  'paro,',
#  'otro',
#  'más.',
#  'queda',
#  'mucho',
#  'por',
#  'enseñar,',
#  'también',
#  'mucho',
#  'por',
#  'aprender.',
#  '¿pedófilos?',
#  'realidad',
#  'felicidad',
#  'esta',
#  'una',
#  'carcajada,',
#  'por',
#  'ahí',
#  'hay',
#  'payasos',
#  'que',
#  'rien',
#  'tristeza.',
#  '@nemesisadh',
#  'trata',
#  'mas',
#  'vivencias',
#  'menos',
#  'aventuras.',
#  'llegado',
#  'gerente',
#  'mente.',
#  'hacerte',
#  'amor',
#  'lleno',
#  'pasión',
#  'enojo.',
#  'llegar',
#  'arriba',
#  'fácil,',
#  'difícil',
#  'mantenerse.',
#  'trato',
#  'tratar',
#  'nadie.',
#  'alegría',
#  'muere',
#  'con',
#  'noche',
#  'cada',
#  'amanecer.',
#  'camina',
#  'solo',
#  'con',
#  'varios,',
#  'andar',
#  'con',
#  'tanta',
#  'gente',
#  'este',
#  'tiempo',
#  'resulta',
#  'necesario.',
#  'quiero.',
#  'ayer',
#  'fue',
#  'una',
#  'locura.',
#  'cerebro',
#  'respira',
#  'aires',
#  'grandeza.',
#  'dedico',
#  'punto',
#  'final.',
#  'que',
#  'mañana',
#  'sea',
#  'buen',
#  'día.',
#  'ojala',
#  'salga',
#  'cinaruco',
#  'semana',
#  'santa.',
#  'buena',
#  'noche.',
#  'ayudenla,',
#  'para',
#  'una',
#  'tarea.',
#  'manda',
#  'todo',
#  'mierda.',
#  'quiero',
#  'salir',
#  'vacaciones.',
#  'mmm.',
#  'darling.',
#  'buenas',
#  'noches.',
#  'comunicación',
#  'que',
#  'corazón',
#  'limpie.',
#  'feliz',
#  'año',
#  'becerros.',
#  'haces',
#  'mas',
#  'daño',
#  'estando',
#  'solo',
#  'aguantando.',
#  'falta',
#  'carro',
#  'manejo',
#  'lenguaje.',
#  'quiero',
#  'comer',
#  'ponqué',
#  'esos.',
#  'veo',
#  'que',
#  'andar',
#  'siempre',
#  'con',
#  'sueño',
#  'tan',
#  'malo.',
#  'lindo',
#  'avatar,',
#  'tremendas',
#  'tetas.',
#  'pero',
#  'mañana',
#  'esta',
#  'rudo.',
#  'enseñale',
#  'las',
#  'tetas,',
#  'enamoraras.',
#  '¿quien',
#  'hace',
#  'responsable',
#  'tanta',
#  'esperanza',
#  'ese',
#  'futuro',
#  'mejor.',
#  "'la",
#  'soledad',
#  'manda',
#  'decir',
#  'que',
#  'por',
#  "tí.'",
#  'camina',
#  'solo,',
#  'con',
#  'varios.',
#  'ensuciare',
#  'para',
#  'nunca',
#  'tener',
#  'dinero',
#  'sucio.',
#  'examen',
#  'escribiré:',
#  "'pa",
#  'kieres',
#  'saber',
#  'eso',
#  'jajaj',
#  "saludos.'",
#  'coño',
#  'si.',
#  'maldita',
#  'impotencia.',
#  'ella',
#  'muerte',
#  'para',
#  'mi.',
#  'mueren',
#  'las',
#  'personas,',
#  'pero',
#  'sus',
#  'ideas.',
#  'que',
#  'tripeo',
#  'ver',
#  'juego',
#  'con',
#  'primo',
#  'ladilla',
#  'caraquista.',
#  'rap',
#  'full',
#  'volumen.',
#  'con',
#  'errores,',
#  'con',
#  'aciertos.',
#  '@heeydane',
#  'woooo',
#  '¿mono',
#  'ardilla?',
#  'que',
#  'deprimente',
#  'esta',
#  'situación.',
#  'quita',
#  'cara',
#  'cañón',
#  'que',
#  'compraste.',
#  'llegar',
#  'arriba',
#  'fácil,',
#  'difícil',
#  'mantenerse.',
#  'quiero',
#  'que',
#  'represente',
#  'alguien',
#  'que',
#  'sea',
#  'yo.',
#  'las',
#  'sequoia.',
#  'peor',
#  'fue',
#  'cuando',
#  'levante.',
#  'perro',
#  'solitario',
#  'que',
#  'camina',
#  'por',
#  'ciudad.',
#  'que',
#  'locura',
#  'anoche.',
#  'educado',
#  'hacia',
#  'placer',
#  'escuchar',
#  'aprender.',
#  'si.',
#  'una',
#  'minivan',
#  'con',
#  'hp,',
#  'que',
#  'bien.',
#  '¿acaso',
#  'deseo',
#  'amor',
#  'que',
#  'estoy',
#  'sintiendo',
#  'por',
#  'ti?',
#  'unas',
#  'manos',
#  'que',
#  'nunca',
#  'tocaran',
#  'que',
#  'mente',
#  'imagina.',
#  'aveces',
#  'silencio',
#  'aturde.',
#  'pueden',
#  'hacer',
#  'una',
#  'mierda',
#  'solos',
#  'quieren',
#  'que',
#  'otro',
#  'haga.',
#  '-me',
#  'estacionare',
#  'aquí.',
#  '-ahí',
#  'viene',
#  'ex,',
#  'actúa',
#  'normal.',
#  'quien',
#  'odia',
#  'amor',
#  'termina',
#  'enamorandose.',
#  'luz',
#  'brilla',
#  'por',
#  'afuera',
#  'pero',
#  'por',
#  'dentro',
#  'oscuridad',
#  'asecha.',
#  'sendo',
#  'beta',
#  'chamo.',
#  'entonces',
#  'cuando',
#  'vayas.',
#  'niña',
#  'vino',
#  'periodo',
#  'ayer.',
#  '-¿y',
#  'como',
#  'vas',
#  'matemáticas?',
#  '-como',
#  'whatsapp.',
#  'presentaron',
#  'ignoro',
#  'porque',
#  'soy',
#  'negrito,',
#  'pero',
#  'esa',
#  'desquito.',
#  'gustan',
#  'las',
#  'canciones',
#  'tego',
#  ...]

# %% [markdown]
# ### Remove symbols

# %%
data_nosymbols = remove_symbols(data_tokens)

# %%
data_nosymbols[0]
# Out:
# ['una',
#  'cadena',
#  'tan',
#  'fuerte',
#  'como',
#  'eslabón',
#  'más',
#  'frágil',
#  'peor',
#  'error',
#  'que',
#  'alguien',
#  'puede',
#  'cometer',
#  'creerle',
#  'político',
#  'que',
#  'beta',
#  'pensé',
#  'que',
#  'estábamos',
#  'comenzando',
#  'mes',
#  'julio',
#  'sueño',
#  'ven',
#  'mi',
#  'khe',
#  'buen',
#  'día',
#  'todos',
#  'los',
#  'que',
#  'leen',
#  'esto',
#  'que',
#  'está',
#  'hace',
#  'falta',
#  'cuando',
#  'tenga',
#  'otros',
#  'perros',
#  'los',
#  'llamaría',
#  'delta',
#  'tomahowk',
#  'feliz',
#  'cumpleaños',
#  'amorsote',
#  '@heeydane',
#  'voy',
#  'con',
#  'calma',
#  'sin',
#  'apuro',
#  'porque',
#  'gusta',
#  'estar',
#  'gastando',
#  'pólvora',
#  'zamuros',
#  'que',
#  'tiene',
#  'argumento',
#  'insulta',
#  'responde',
#  'con',
#  'preguntas',
#  'este',
#  'país',
#  'necesita',
#  'personas',
#  'profesionales',
#  'solo',
#  'nivel',
#  'laboral',
#  'sino',
#  'nivel',
#  'personal',
#  'este',
#  'momento',
#  'desearía',
#  'estar',
#  'orilla',
#  'playa',
#  'con',
#  'unas',
#  'cervezas',
#  'todo',
#  'que',
#  'hagas',
#  'importa',
#  'nacidos',
#  'para',
#  'correr',
#  'bebe',
#  'todos',
#  'los',
#  'sábados',
#  'vida',
#  'kriss',
#  'kyle',
#  'que',
#  'duren',
#  'momentos',
#  'duros',
#  'gallo',
#  'pone',
#  'peligroso',
#  'perdedor',
#  'que',
#  'tiene',
#  'nada',
#  'que',
#  'perder',
#  '“mas',
#  'que',
#  'sonrisa',
#  'analicen',
#  'mirada',
#  'una',
#  'persona”',
#  'feliz',
#  'año',
#  'lacras',
#  'deseo',
#  'mucho',
#  'dinero',
#  'esteros',
#  'morichales',
#  'lento',
#  'camino',
#  'hacia',
#  'ninguna',
#  'parte',
#  'nunca',
#  'tarde',
#  'para',
#  'cambiar',
#  'ahora',
#  'nunca',
#  'quieres',
#  'pescar',
#  'grandes',
#  'peces',
#  'tienes',
#  'que',
#  'aguas',
#  'profundas',
#  'historia',
#  'vida',
#  'gustan',
#  'mucho',
#  'las',
#  'mujeres',
#  'con',
#  'lentes',
#  '@karlosgodoy3',
#  'que',
#  'marico',
#  'ese',
#  'muchacho',
#  'sus',
#  'temas',
#  'hablan',
#  'millones',
#  'kilos',
#  'pero',
#  'andan',
#  'pie',
#  'con',
#  'currículum',
#  'sobre',
#  'manila',
#  'bajo',
#  'axila',
#  'que',
#  'reales',
#  'que',
#  'por',
#  'pique',
#  'riales',
#  'alteran',
#  'lento',
#  'pero',
#  'seguro',
#  'sin',
#  'apuro',
#  'que',
#  'las',
#  'sepa',
#  'todas',
#  'que',
#  'desconocen',
#  'verdades',
#  'ocultas',
#  'melancolía',
#  'existiera',
#  'los',
#  'colibrí',
#  'pondrían',
#  'eructar',
#  'que',
#  'bonita',
#  'esa',
#  'nueva',
#  'asamblea',
#  'fuego',
#  'helado',
#  'nunca',
#  'vida',
#  'esperes',
#  'algo',
#  'alguien',
#  'que',
#  'ladilla',
#  'desarmar',
#  'ver',
#  'que',
#  'tienes',
#  'repuesto',
#  'equivocado',
#  'sabado',
#  'soy',
#  'propia',
#  'piedra',
#  'zapato',
#  'hay',
#  'muro',
#  'hay',
#  'barrera',
#  'hay',
#  'muralla',
#  'cosas',
#  'que',
#  'solo',
#  'sucederán',
#  'las',
#  'haces',
#  'mismo',
#  'usted',
#  'sabe',
#  'que',
#  'quiere',
#  'esta',
#  'jodido',
#  'porque',
#  'nada',
#  'bien',
#  'nadar',
#  'por',
#  'vida',
#  'confundido',
#  'debí',
#  'enviar',
#  'eso',
#  'gusta',
#  'reparar',
#  'mejorar',
#  'las',
#  'cosas',
#  'estos',
#  'momentos',
#  'quiero',
#  'beber',
#  'día',
#  'con',
#  'daneska',
#  'aplomo',
#  'largo',
#  'esta',
#  'shit',
#  'mmmmmmm',
#  'linten',
#  'the',
#  'warrior',
#  'aquí',
#  'somos',
#  'varios',
#  'crew',
#  'necesito',
#  'tirar',
#  'elettra',
#  'lamborghini',
#  'lindo',
#  'nombre',
#  'efectos',
#  'hidrófonos',
#  'puede',
#  'gusta',
#  'hablar',
#  'tiempo',
#  'que',
#  'llevo',
#  'estudiando',
#  'prefiero',
#  'hablar',
#  'que',
#  'falta',
#  'por',
#  'aprender',
#  'rap',
#  'amazónico',
#  'anti',
#  'farándula',
#  'pedagógico',
#  'anti',
#  'dramático',
#  'con',
#  'sentido',
#  'lógico',
#  'distancia',
#  'beta',
#  'bale',
#  'berga',
#  'bida',
#  'listo',
#  'para',
#  'recibir',
#  'después',
#  'hacer',
#  'mal',
#  'pan',
#  'con',
#  'diablito',
#  'salsa',
#  'comida',
#  'dioses',
#  'amen',
#  'horario',
#  'muy',
#  'bipolar',
#  'los',
#  'lunes',
#  'entro',
#  'las',
#  'los',
#  'martes',
#  'las',
#  'luego',
#  'los',
#  'miércoles',
#  'las',
#  'postea',
#  'también',
#  'las',
#  'oriana',
#  'hola',
#  'vale',
#  'trabaja',
#  'silencio',
#  'llama',
#  'atención',
#  'donde',
#  'pisa',
#  'digitel',
#  'sube',
#  'los',
#  'planes',
#  'tengo',
#  'señal',
#  'que',
#  'maravilla',
#  'culmino',
#  'semana',
#  'vacaciones',
#  'seria',
#  'depinga',
#  'trabajar',
#  'rocket',
#  'bunny',
#  'liberty',
#  'walk',
#  'colega',
#  'acá',
#  'venezuela',
#  'que',
#  'vende',
#  'paraguas',
#  'mismo',
#  'que',
#  'hace',
#  'que',
#  'llueva',
#  'tengo',
#  'quien',
#  'llegar',
#  'arriba',
#  'fácil',
#  'difícil',
#  'mantenerse',
#  'hoy',
#  'andaba',
#  'con',
#  'gocho',
#  'par',
#  'despechados',
#  'exprimo',
#  'las',
#  'canciones',
#  'buenos',
#  'cantautores',
#  'vacilen',
#  'ignoren',
#  'que',
#  'duren',
#  'momentos',
#  'duros',
#  'buenos',
#  'días',
#  'seguiré',
#  'durmiendo',
#  'preguntamos',
#  'cómo',
#  'cuando',
#  'como',
#  'justicia',
#  'muda',
#  'deambula',
#  'mula',
#  'por',
#  'ahí',
#  'compae',
#  'cuento',
#  'conmigo',
#  'mismo',
#  'voy',
#  'paso',
#  'llano',
#  'esperanza',
#  'error',
#  'unos',
#  'roban',
#  'otros',
#  'luchan',
#  'para',
#  'poder',
#  'vivir',
#  'todos',
#  'hablan',
#  'futbol',
#  'quedo',
#  'igual',
#  'que',
#  'clases',
#  'matemáticas',
#  'día',
#  'andaba',
#  'con',
#  'mis',
#  'panas',
#  'buscamos',
#  'pique',
#  'una',
#  'tundra',
#  'nos',
#  'dejo',
#  'fue',
#  'botados',
#  'cuerrrpo',
#  'cobaarrrde',
#  'como',
#  'meneaas',
#  'cargo',
#  'una',
#  'peaaa',
#  'que',
#  'dios',
#  'guaaarrrrde',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer',
#  'vida',
#  'una',
#  'pretenciosa',
#  'mientras',
#  'mas',
#  'bella',
#  'flor',
#  'mas',
#  'espinosa',
#  'miedo',
#  'mas',
#  'grande',
#  'que',
#  'adversario',
#  'los',
#  'verdaderos',
#  'guerreros',
#  'caminan',
#  'senderos',
#  'solos',
#  'con',
#  'aplomo',
#  'todo',
#  'que',
#  'mira',
#  'termina',
#  'paranoico',
#  'ahora',
#  'hay',
#  'pocos',
#  'talleres',
#  'venezuela',
#  'con',
#  'esas',
#  'maquinas',
#  'nada',
#  'imposible',
#  'tienes',
#  'valor',
#  'coraje',
#  'buen',
#  'plan',
#  'deja',
#  'tus',
#  'miedos',
#  'atras',
#  'termofluidos',
#  'enreda',
#  'burda',
#  'rompe',
#  'las',
#  'cadenas',
#  'que',
#  'atan',
#  'tanta',
#  'escoria',
#  'sobrados',
#  'sobrando',
#  'todo',
#  'los',
#  'que',
#  'vive',
#  'rap',
#  'real',
#  'rap',
#  'del',
#  'bueno',
#  'del',
#  'caribe',
#  'hermosa',
#  'con',
#  'sus',
#  'pecas',
#  'lunares',
#  'hoy',
#  'palio',
#  'gtr',
#  'como',
#  'venga',
#  'necesito',
#  'sexo',
#  'esa',
#  'camioneta',
#  'perfecta',
#  'necesito',
#  'cuadre',
#  '@jmesza',
#  'los',
#  'san',
#  'felipe',
#  'son',
#  'maricos',
#  'dicen',
#  'verdades',
#  'caen',
#  'lona',
#  'ainsss',
#  'tan',
#  'bello',
#  'lucho',
#  'por',
#  'sonrisa',
#  'madre',
#  'que',
#  'vale',
#  'millón',
#  'fue',
#  'culpa',
#  'fue',
#  'mía',
#  'fue',
#  'destino',
#  'fue',
#  'vida',
#  'puedo',
#  'andar',
#  'sin',
#  'bolívar',
#  'bolsillo',
#  'pero',
#  'tranquilo',
#  'porque',
#  'soy',
#  'sencillo',
#  'malo',
#  'mentir',
#  'otra',
#  'noche',
#  'como',
#  'sábado',
#  '@somos412',
#  'buen',
#  'día',
#  'informo',
#  'que',
#  'puerto',
#  'cabello',
#  'específicamente',
#  'borburata',
#  'hay',
#  'servicio',
#  'esperamos',
#  'pronta',
#  'solución',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer',
#  'malpario',
#  'dolor',
#  'cabeza',
#  'sencillo',
#  'práctico',
#  'natural',
#  'que',
#  'soy',
#  'buen',
#  'dj',
#  'paso',
#  'todo',
#  'día',
#  'pensando',
#  'hacer',
#  'tarea',
#  'final',
#  'hago',
#  'coño',
#  'traes',
#  'comida',
#  'algo',
#  'para',
#  'beber',
#  'hay',
#  'peo',
#  'carcajadas',
#  'retumban',
#  'pasa',
#  'pierdes',
#  'nada',
#  'ganas',
#  'mucho',
#  'decirlas',
#  'que',
#  'buen',
#  'día',
#  'alcohol',
#  'para',
#  'todo',
#  'iutpc',
#  'paro',
#  'otro',
#  'más',
#  'queda',
#  'mucho',
#  'por',
#  'enseñar',
#  'también',
#  'mucho',
#  'por',
#  'aprender',
#  'pedófilos',
#  'realidad',
#  'felicidad',
#  'esta',
#  'una',
#  'carcajada',
#  'por',
#  'ahí',
#  'hay',
#  'payasos',
#  'que',
#  'rien',
#  'tristeza',
#  '@nemesisadh',
#  'trata',
#  'mas',
#  'vivencias',
#  'menos',
#  'aventuras',
#  'llegado',
#  'gerente',
#  'mente',
#  'hacerte',
#  'amor',
#  'lleno',
#  'pasión',
#  'enojo',
#  'llegar',
#  'arriba',
#  'fácil',
#  'difícil',
#  'mantenerse',
#  'trato',
#  'tratar',
#  'nadie',
#  'alegría',
#  'muere',
#  'con',
#  'noche',
#  'cada',
#  'amanecer',
#  'camina',
#  'solo',
#  'con',
#  'varios',
#  'andar',
#  'con',
#  'tanta',
#  'gente',
#  'este',
#  'tiempo',
#  'resulta',
#  'necesario',
#  'quiero',
#  'ayer',
#  'fue',
#  'una',
#  'locura',
#  'cerebro',
#  'respira',
#  'aires',
#  'grandeza',
#  'dedico',
#  'punto',
#  'final',
#  'que',
#  'mañana',
#  'sea',
#  'buen',
#  'día',
#  'ojala',
#  'salga',
#  'cinaruco',
#  'semana',
#  'santa',
#  'buena',
#  'noche',
#  'ayudenla',
#  'para',
#  'una',
#  'tarea',
#  'manda',
#  'todo',
#  'mierda',
#  'quiero',
#  'salir',
#  'vacaciones',
#  'mmm',
#  'darling',
#  'buenas',
#  'noches',
#  'comunicación',
#  'que',
#  'corazón',
#  'limpie',
#  'feliz',
#  'año',
#  'becerros',
#  'haces',
#  'mas',
#  'daño',
#  'estando',
#  'solo',
#  'aguantando',
#  'falta',
#  'carro',
#  'manejo',
#  'lenguaje',
#  'quiero',
#  'comer',
#  'ponqué',
#  'esos',
#  'veo',
#  'que',
#  'andar',
#  'siempre',
#  'con',
#  'sueño',
#  'tan',
#  'malo',
#  'lindo',
#  'avatar',
#  'tremendas',
#  'tetas',
#  'pero',
#  'mañana',
#  'esta',
#  'rudo',
#  'enseñale',
#  'las',
#  'tetas',
#  'enamoraras',
#  'quien',
#  'hace',
#  'responsable',
#  'tanta',
#  'esperanza',
#  'ese',
#  'futuro',
#  'mejor',
#  'la',
#  'soledad',
#  'manda',
#  'decir',
#  'que',
#  'por',
#  'tí',
#  'camina',
#  'solo',
#  'con',
#  'varios',
#  'ensuciare',
#  'para',
#  'nunca',
#  'tener',
#  'dinero',
#  'sucio',
#  'examen',
#  'escribiré',
#  'pa',
#  'kieres',
#  'saber',
#  'eso',
#  'jajaj',
#  'saludos',
#  'coño',
#  'si',
#  'maldita',
#  'impotencia',
#  'ella',
#  'muerte',
#  'para',
#  'mi',
#  'mueren',
#  'las',
#  'personas',
#  'pero',
#  'sus',
#  'ideas',
#  'que',
#  'tripeo',
#  'ver',
#  'juego',
#  'con',
#  'primo',
#  'ladilla',
#  'caraquista',
#  'rap',
#  'full',
#  'volumen',
#  'con',
#  'errores',
#  'con',
#  'aciertos',
#  '@heeydane',
#  'woooo',
#  'mono',
#  'ardilla',
#  'que',
#  'deprimente',
#  'esta',
#  'situación',
#  'quita',
#  'cara',
#  'cañón',
#  'que',
#  'compraste',
#  'llegar',
#  'arriba',
#  'fácil',
#  'difícil',
#  'mantenerse',
#  'quiero',
#  'que',
#  'represente',
#  'alguien',
#  'que',
#  'sea',
#  'yo',
#  'las',
#  'sequoia',
#  'peor',
#  'fue',
#  'cuando',
#  'levante',
#  'perro',
#  'solitario',
#  'que',
#  'camina',
#  'por',
#  'ciudad',
#  'que',
#  'locura',
#  'anoche',
#  'educado',
#  'hacia',
#  'placer',
#  'escuchar',
#  'aprender',
#  'si',
#  'una',
#  'minivan',
#  'con',
#  'hp',
#  'que',
#  'bien',
#  'acaso',
#  'deseo',
#  'amor',
#  'que',
#  'estoy',
#  'sintiendo',
#  'por',
#  'ti',
#  'unas',
#  'manos',
#  'que',
#  'nunca',
#  'tocaran',
#  'que',
#  'mente',
#  'imagina',
#  'aveces',
#  'silencio',
#  'aturde',
#  'pueden',
#  'hacer',
#  'una',
#  'mierda',
#  'solos',
#  'quieren',
#  'que',
#  'otro',
#  'haga',
#  'me',
#  'estacionare',
#  'aquí',
#  'ahí',
#  'viene',
#  'ex',
#  'actúa',
#  'normal',
#  'quien',
#  'odia',
#  'amor',
#  'termina',
#  'enamorandose',
#  'luz',
#  'brilla',
#  'por',
#  'afuera',
#  'pero',
#  'por',
#  'dentro',
#  'oscuridad',
#  'asecha',
#  'sendo',
#  'beta',
#  'chamo',
#  'entonces',
#  'cuando',
#  'vayas',
#  'niña',
#  'vino',
#  'periodo',
#  'ayer',
#  'y',
#  'como',
#  'vas',
#  'matemáticas',
#  'como',
#  'whatsapp',
#  'presentaron',
#  'ignoro',
#  'porque',
#  'soy',
#  'negrito',
#  'pero',
#  'esa',
#  'desquito',
#  'gustan',
#  'las',
#  'canciones',
#  'tego',
#  ...]

# %% [markdown]
# ### Remove accents

# %%
data_noaccents = remove_accents(data_nosymbols)

# %%
data_noaccents[0]
# Out:
# ['una',
#  'cadena',
#  'tan',
#  'fuerte',
#  'como',
#  'eslabon',
#  'mas',
#  'fragil',
#  'peor',
#  'error',
#  'que',
#  'alguien',
#  'puede',
#  'cometer',
#  'creerle',
#  'politico',
#  'que',
#  'beta',
#  'pense',
#  'que',
#  'estabamos',
#  'comenzando',
#  'mes',
#  'julio',
#  'sueno',
#  'ven',
#  'mi',
#  'khe',
#  'buen',
#  'dia',
#  'todos',
#  'los',
#  'que',
#  'leen',
#  'esto',
#  'que',
#  'esta',
#  'hace',
#  'falta',
#  'cuando',
#  'tenga',
#  'otros',
#  'perros',
#  'los',
#  'llamaria',
#  'delta',
#  'tomahowk',
#  'feliz',
#  'cumpleanos',
#  'amorsote',
#  '@heeydane',
#  'voy',
#  'con',
#  'calma',
#  'sin',
#  'apuro',
#  'porque',
#  'gusta',
#  'estar',
#  'gastando',
#  'polvora',
#  'zamuros',
#  'que',
#  'tiene',
#  'argumento',
#  'insulta',
#  'responde',
#  'con',
#  'preguntas',
#  'este',
#  'pais',
#  'necesita',
#  'personas',
#  'profesionales',
#  'solo',
#  'nivel',
#  'laboral',
#  'sino',
#  'nivel',
#  'personal',
#  'este',
#  'momento',
#  'desearia',
#  'estar',
#  'orilla',
#  'playa',
#  'con',
#  'unas',
#  'cervezas',
#  'todo',
#  'que',
#  'hagas',
#  'importa',
#  'nacidos',
#  'para',
#  'correr',
#  'bebe',
#  'todos',
#  'los',
#  'sabados',
#  'vida',
#  'kriss',
#  'kyle',
#  'que',
#  'duren',
#  'momentos',
#  'duros',
#  'gallo',
#  'pone',
#  'peligroso',
#  'perdedor',
#  'que',
#  'tiene',
#  'nada',
#  'que',
#  'perder',
#  '“mas',
#  'que',
#  'sonrisa',
#  'analicen',
#  'mirada',
#  'una',
#  'persona”',
#  'feliz',
#  'ano',
#  'lacras',
#  'deseo',
#  'mucho',
#  'dinero',
#  'esteros',
#  'morichales',
#  'lento',
#  'camino',
#  'hacia',
#  'ninguna',
#  'parte',
#  'nunca',
#  'tarde',
#  'para',
#  'cambiar',
#  'ahora',
#  'nunca',
#  'quieres',
#  'pescar',
#  'grandes',
#  'peces',
#  'tienes',
#  'que',
#  'aguas',
#  'profundas',
#  'historia',
#  'vida',
#  'gustan',
#  'mucho',
#  'las',
#  'mujeres',
#  'con',
#  'lentes',
#  '@karlosgodoy3',
#  'que',
#  'marico',
#  'ese',
#  'muchacho',
#  'sus',
#  'temas',
#  'hablan',
#  'millones',
#  'kilos',
#  'pero',
#  'andan',
#  'pie',
#  'con',
#  'curriculum',
#  'sobre',
#  'manila',
#  'bajo',
#  'axila',
#  'que',
#  'reales',
#  'que',
#  'por',
#  'pique',
#  'riales',
#  'alteran',
#  'lento',
#  'pero',
#  'seguro',
#  'sin',
#  'apuro',
#  'que',
#  'las',
#  'sepa',
#  'todas',
#  'que',
#  'desconocen',
#  'verdades',
#  'ocultas',
#  'melancolia',
#  'existiera',
#  'los',
#  'colibri',
#  'pondrian',
#  'eructar',
#  'que',
#  'bonita',
#  'esa',
#  'nueva',
#  'asamblea',
#  'fuego',
#  'helado',
#  'nunca',
#  'vida',
#  'esperes',
#  'algo',
#  'alguien',
#  'que',
#  'ladilla',
#  'desarmar',
#  'ver',
#  'que',
#  'tienes',
#  'repuesto',
#  'equivocado',
#  'sabado',
#  'soy',
#  'propia',
#  'piedra',
#  'zapato',
#  'hay',
#  'muro',
#  'hay',
#  'barrera',
#  'hay',
#  'muralla',
#  'cosas',
#  'que',
#  'solo',
#  'sucederan',
#  'las',
#  'haces',
#  'mismo',
#  'usted',
#  'sabe',
#  'que',
#  'quiere',
#  'esta',
#  'jodido',
#  'porque',
#  'nada',
#  'bien',
#  'nadar',
#  'por',
#  'vida',
#  'confundido',
#  'debi',
#  'enviar',
#  'eso',
#  'gusta',
#  'reparar',
#  'mejorar',
#  'las',
#  'cosas',
#  'estos',
#  'momentos',
#  'quiero',
#  'beber',
#  'dia',
#  'con',
#  'daneska',
#  'aplomo',
#  'largo',
#  'esta',
#  'shit',
#  'mmmmmmm',
#  'linten',
#  'the',
#  'warrior',
#  'aqui',
#  'somos',
#  'varios',
#  'crew',
#  'necesito',
#  'tirar',
#  'elettra',
#  'lamborghini',
#  'lindo',
#  'nombre',
#  'efectos',
#  'hidrofonos',
#  'puede',
#  'gusta',
#  'hablar',
#  'tiempo',
#  'que',
#  'llevo',
#  'estudiando',
#  'prefiero',
#  'hablar',
#  'que',
#  'falta',
#  'por',
#  'aprender',
#  'rap',
#  'amazonico',
#  'anti',
#  'farandula',
#  'pedagogico',
#  'anti',
#  'dramatico',
#  'con',
#  'sentido',
#  'logico',
#  'distancia',
#  'beta',
#  'bale',
#  'berga',
#  'bida',
#  'listo',
#  'para',
#  'recibir',
#  'despues',
#  'hacer',
#  'mal',
#  'pan',
#  'con',
#  'diablito',
#  'salsa',
#  'comida',
#  'dioses',
#  'amen',
#  'horario',
#  'muy',
#  'bipolar',
#  'los',
#  'lunes',
#  'entro',
#  'las',
#  'los',
#  'martes',
#  'las',
#  'luego',
#  'los',
#  'miercoles',
#  'las',
#  'postea',
#  'tambien',
#  'las',
#  'oriana',
#  'hola',
#  'vale',
#  'trabaja',
#  'silencio',
#  'llama',
#  'atencion',
#  'donde',
#  'pisa',
#  'digitel',
#  'sube',
#  'los',
#  'planes',
#  'tengo',
#  'senal',
#  'que',
#  'maravilla',
#  'culmino',
#  'semana',
#  'vacaciones',
#  'seria',
#  'depinga',
#  'trabajar',
#  'rocket',
#  'bunny',
#  'liberty',
#  'walk',
#  'colega',
#  'aca',
#  'venezuela',
#  'que',
#  'vende',
#  'paraguas',
#  'mismo',
#  'que',
#  'hace',
#  'que',
#  'llueva',
#  'tengo',
#  'quien',
#  'llegar',
#  'arriba',
#  'facil',
#  'dificil',
#  'mantenerse',
#  'hoy',
#  'andaba',
#  'con',
#  'gocho',
#  'par',
#  'despechados',
#  'exprimo',
#  'las',
#  'canciones',
#  'buenos',
#  'cantautores',
#  'vacilen',
#  'ignoren',
#  'que',
#  'duren',
#  'momentos',
#  'duros',
#  'buenos',
#  'dias',
#  'seguire',
#  'durmiendo',
#  'preguntamos',
#  'como',
#  'cuando',
#  'como',
#  'justicia',
#  'muda',
#  'deambula',
#  'mula',
#  'por',
#  'ahi',
#  'compae',
#  'cuento',
#  'conmigo',
#  'mismo',
#  'voy',
#  'paso',
#  'llano',
#  'esperanza',
#  'error',
#  'unos',
#  'roban',
#  'otros',
#  'luchan',
#  'para',
#  'poder',
#  'vivir',
#  'todos',
#  'hablan',
#  'futbol',
#  'quedo',
#  'igual',
#  'que',
#  'clases',
#  'matematicas',
#  'dia',
#  'andaba',
#  'con',
#  'mis',
#  'panas',
#  'buscamos',
#  'pique',
#  'una',
#  'tundra',
#  'nos',
#  'dejo',
#  'fue',
#  'botados',
#  'cuerrrpo',
#  'cobaarrrde',
#  'como',
#  'meneaas',
#  'cargo',
#  'una',
#  'peaaa',
#  'que',
#  'dios',
#  'guaaarrrrde',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer',
#  'vida',
#  'una',
#  'pretenciosa',
#  'mientras',
#  'mas',
#  'bella',
#  'flor',
#  'mas',
#  'espinosa',
#  'miedo',
#  'mas',
#  'grande',
#  'que',
#  'adversario',
#  'los',
#  'verdaderos',
#  'guerreros',
#  'caminan',
#  'senderos',
#  'solos',
#  'con',
#  'aplomo',
#  'todo',
#  'que',
#  'mira',
#  'termina',
#  'paranoico',
#  'ahora',
#  'hay',
#  'pocos',
#  'talleres',
#  'venezuela',
#  'con',
#  'esas',
#  'maquinas',
#  'nada',
#  'imposible',
#  'tienes',
#  'valor',
#  'coraje',
#  'buen',
#  'plan',
#  'deja',
#  'tus',
#  'miedos',
#  'atras',
#  'termofluidos',
#  'enreda',
#  'burda',
#  'rompe',
#  'las',
#  'cadenas',
#  'que',
#  'atan',
#  'tanta',
#  'escoria',
#  'sobrados',
#  'sobrando',
#  'todo',
#  'los',
#  'que',
#  'vive',
#  'rap',
#  'real',
#  'rap',
#  'del',
#  'bueno',
#  'del',
#  'caribe',
#  'hermosa',
#  'con',
#  'sus',
#  'pecas',
#  'lunares',
#  'hoy',
#  'palio',
#  'gtr',
#  'como',
#  'venga',
#  'necesito',
#  'sexo',
#  'esa',
#  'camioneta',
#  'perfecta',
#  'necesito',
#  'cuadre',
#  '@jmesza',
#  'los',
#  'san',
#  'felipe',
#  'son',
#  'maricos',
#  'dicen',
#  'verdades',
#  'caen',
#  'lona',
#  'ainsss',
#  'tan',
#  'bello',
#  'lucho',
#  'por',
#  'sonrisa',
#  'madre',
#  'que',
#  'vale',
#  'millon',
#  'fue',
#  'culpa',
#  'fue',
#  'mia',
#  'fue',
#  'destino',
#  'fue',
#  'vida',
#  'puedo',
#  'andar',
#  'sin',
#  'bolivar',
#  'bolsillo',
#  'pero',
#  'tranquilo',
#  'porque',
#  'soy',
#  'sencillo',
#  'malo',
#  'mentir',
#  'otra',
#  'noche',
#  'como',
#  'sabado',
#  '@somos412',
#  'buen',
#  'dia',
#  'informo',
#  'que',
#  'puerto',
#  'cabello',
#  'especificamente',
#  'borburata',
#  'hay',
#  'servicio',
#  'esperamos',
#  'pronta',
#  'solucion',
#  'vive',
#  'vida',
#  'sin',
#  'miedo',
#  'caer',
#  'malpario',
#  'dolor',
#  'cabeza',
#  'sencillo',
#  'practico',
#  'natural',
#  'que',
#  'soy',
#  'buen',
#  'dj',
#  'paso',
#  'todo',
#  'dia',
#  'pensando',
#  'hacer',
#  'tarea',
#  'final',
#  'hago',
#  'cono',
#  'traes',
#  'comida',
#  'algo',
#  'para',
#  'beber',
#  'hay',
#  'peo',
#  'carcajadas',
#  'retumban',
#  'pasa',
#  'pierdes',
#  'nada',
#  'ganas',
#  'mucho',
#  'decirlas',
#  'que',
#  'buen',
#  'dia',
#  'alcohol',
#  'para',
#  'todo',
#  'iutpc',
#  'paro',
#  'otro',
#  'mas',
#  'queda',
#  'mucho',
#  'por',
#  'ensenar',
#  'tambien',
#  'mucho',
#  'por',
#  'aprender',
#  'pedofilos',
#  'realidad',
#  'felicidad',
#  'esta',
#  'una',
#  'carcajada',
#  'por',
#  'ahi',
#  'hay',
#  'payasos',
#  'que',
#  'rien',
#  'tristeza',
#  '@nemesisadh',
#  'trata',
#  'mas',
#  'vivencias',
#  'menos',
#  'aventuras',
#  'llegado',
#  'gerente',
#  'mente',
#  'hacerte',
#  'amor',
#  'lleno',
#  'pasion',
#  'enojo',
#  'llegar',
#  'arriba',
#  'facil',
#  'dificil',
#  'mantenerse',
#  'trato',
#  'tratar',
#  'nadie',
#  'alegria',
#  'muere',
#  'con',
#  'noche',
#  'cada',
#  'amanecer',
#  'camina',
#  'solo',
#  'con',
#  'varios',
#  'andar',
#  'con',
#  'tanta',
#  'gente',
#  'este',
#  'tiempo',
#  'resulta',
#  'necesario',
#  'quiero',
#  'ayer',
#  'fue',
#  'una',
#  'locura',
#  'cerebro',
#  'respira',
#  'aires',
#  'grandeza',
#  'dedico',
#  'punto',
#  'final',
#  'que',
#  'manana',
#  'sea',
#  'buen',
#  'dia',
#  'ojala',
#  'salga',
#  'cinaruco',
#  'semana',
#  'santa',
#  'buena',
#  'noche',
#  'ayudenla',
#  'para',
#  'una',
#  'tarea',
#  'manda',
#  'todo',
#  'mierda',
#  'quiero',
#  'salir',
#  'vacaciones',
#  'mmm',
#  'darling',
#  'buenas',
#  'noches',
#  'comunicacion',
#  'que',
#  'corazon',
#  'limpie',
#  'feliz',
#  'ano',
#  'becerros',
#  'haces',
#  'mas',
#  'dano',
#  'estando',
#  'solo',
#  'aguantando',
#  'falta',
#  'carro',
#  'manejo',
#  'lenguaje',
#  'quiero',
#  'comer',
#  'ponque',
#  'esos',
#  'veo',
#  'que',
#  'andar',
#  'siempre',
#  'con',
#  'sueno',
#  'tan',
#  'malo',
#  'lindo',
#  'avatar',
#  'tremendas',
#  'tetas',
#  'pero',
#  'manana',
#  'esta',
#  'rudo',
#  'ensenale',
#  'las',
#  'tetas',
#  'enamoraras',
#  'quien',
#  'hace',
#  'responsable',
#  'tanta',
#  'esperanza',
#  'ese',
#  'futuro',
#  'mejor',
#  'la',
#  'soledad',
#  'manda',
#  'decir',
#  'que',
#  'por',
#  'ti',
#  'camina',
#  'solo',
#  'con',
#  'varios',
#  'ensuciare',
#  'para',
#  'nunca',
#  'tener',
#  'dinero',
#  'sucio',
#  'examen',
#  'escribire',
#  'pa',
#  'kieres',
#  'saber',
#  'eso',
#  'jajaj',
#  'saludos',
#  'cono',
#  'si',
#  'maldita',
#  'impotencia',
#  'ella',
#  'muerte',
#  'para',
#  'mi',
#  'mueren',
#  'las',
#  'personas',
#  'pero',
#  'sus',
#  'ideas',
#  'que',
#  'tripeo',
#  'ver',
#  'juego',
#  'con',
#  'primo',
#  'ladilla',
#  'caraquista',
#  'rap',
#  'full',
#  'volumen',
#  'con',
#  'errores',
#  'con',
#  'aciertos',
#  '@heeydane',
#  'woooo',
#  'mono',
#  'ardilla',
#  'que',
#  'deprimente',
#  'esta',
#  'situacion',
#  'quita',
#  'cara',
#  'canon',
#  'que',
#  'compraste',
#  'llegar',
#  'arriba',
#  'facil',
#  'dificil',
#  'mantenerse',
#  'quiero',
#  'que',
#  'represente',
#  'alguien',
#  'que',
#  'sea',
#  'yo',
#  'las',
#  'sequoia',
#  'peor',
#  'fue',
#  'cuando',
#  'levante',
#  'perro',
#  'solitario',
#  'que',
#  'camina',
#  'por',
#  'ciudad',
#  'que',
#  'locura',
#  'anoche',
#  'educado',
#  'hacia',
#  'placer',
#  'escuchar',
#  'aprender',
#  'si',
#  'una',
#  'minivan',
#  'con',
#  'hp',
#  'que',
#  'bien',
#  'acaso',
#  'deseo',
#  'amor',
#  'que',
#  'estoy',
#  'sintiendo',
#  'por',
#  'ti',
#  'unas',
#  'manos',
#  'que',
#  'nunca',
#  'tocaran',
#  'que',
#  'mente',
#  'imagina',
#  'aveces',
#  'silencio',
#  'aturde',
#  'pueden',
#  'hacer',
#  'una',
#  'mierda',
#  'solos',
#  'quieren',
#  'que',
#  'otro',
#  'haga',
#  'me',
#  'estacionare',
#  'aqui',
#  'ahi',
#  'viene',
#  'ex',
#  'actúa',
#  'normal',
#  'quien',
#  'odia',
#  'amor',
#  'termina',
#  'enamorandose',
#  'luz',
#  'brilla',
#  'por',
#  'afuera',
#  'pero',
#  'por',
#  'dentro',
#  'oscuridad',
#  'asecha',
#  'sendo',
#  'beta',
#  'chamo',
#  'entonces',
#  'cuando',
#  'vayas',
#  'nina',
#  'vino',
#  'periodo',
#  'ayer',
#  'y',
#  'como',
#  'vas',
#  'matematicas',
#  'como',
#  'whatsapp',
#  'presentaron',
#  'ignoro',
#  'porque',
#  'soy',
#  'negrito',
#  'pero',
#  'esa',
#  'desquito',
#  'gustan',
#  'las',
#  'canciones',
#  'tego',
#  ...]

# %% [markdown]
# ### Remove laughing

# %%
# data_nolaughs = remove_laughing(data_noaccents) 
# need to make more efficient!

# %%
data_words = data_noaccents

# %% [markdown]
# ### Create Bigram/Trigram Models

# %%
# Create Bigram & Trigram Models

# Build the bigram and trigram models - higher threshold fewer phrases.
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %% [markdown]
# ### Remove stopwords (english and spanish)

# %%
data_words_nostops = remove_stopwords(data_words)

# %% [markdown]
# ### Form Bigrams

# %%
data_words_bigrams = make_bigrams(data_words_nostops)

# %% [markdown]
# ### Perform lemmatization

# %%
nlp = spacy.load('es', disable=['parser', 'ner'], max_length = 30000000)
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
data_lemmatized[25]
# Out:
# ['lanzar',
#  'victoria',
#  'portar',
#  'hombre',
#  'coraje',
#  'defender',
#  'patrio',
#  'pesadilla',
#  'honor_lealtad',
#  'dignidad',
#  'valor',
#  'independencia',
#  'via',
#  'jajajajajaj_faltaron',
#  'disociar',
#  'video',
#  'discursar',
#  'vladimir_padrino',
#  'lopez',
#  'reír',
#  'jajaja',
#  'vamoss',
#  'marcar',
#  'peligroso',
#  'volar',
#  'ramo',
#  'instrumentar',
#  'duenos_imperiales',
#  'bajo_egida',
#  'ramosallup666',
#  'punto',
#  'control',
#  'par',
#  'nacional',
#  'morrocoy',
#  'heredero',
#  'glorias_simon',
#  'bolivar',
#  'difundir',
#  'imagen',
#  'reír',
#  'jajaja',
#  'felizjueves',
#  'amor',
#  'nacer',
#  'aqui',
#  'patria_singular',
#  'video',
#  'adiestramiento',
#  'trabajar',
#  'equipar',
#  'soldar',
#  'tanque',
#  'binomio',
#  'defensa',
#  'integral',
#  'pais',
#  'hombres_mujeres',
#  'fanb',
#  'pecho_afuera',
#  'maxima',
#  'concienciar',
#  'moral',
#  'vosotros',
#  'garantia',
#  'paz',
#  'idiota',
#  'nunca',
#  'vida',
#  'portado_uniforme',
#  'militar',
#  'glorioso',
#  'fanb',
#  'miserable_ht',
#  'camarada',
#  'alerta_vean',
#  'tweet',
#  'tumbar',
#  'tendencia',
#  'campana',
#  'mas',
#  'uniformar',
#  'heredero',
#  'glorias_simon',
#  'bolivar',
#  'hoy',
#  'reafirman_caracter',
#  'lucha_frontal',
#  'gnb',
#  'alerta_vean',
#  'tumbar',
#  'tendencia',
#  'compraria',
#  'planchar',
#  'nuevo',
#  'henry_ramos',
#  'allup',
#  'ramosallup666',
#  'hombre',
#  'heroes',
#  'batallar',
#  'solo',
#  'objetivar',
#  'independencia',
#  'venezuela',
#  'pensamiento',
#  'comandante_supremo',
#  'eterno',
#  'ramosallup666',
#  'viejo_dinosaurio',
#  'heredero',
#  'glorias_simon',
#  'bolivar',
#  '@hramosallup_ladron',
#  'ramosallup666',
#  'kilometraje',
#  'verde',
#  'poder',
#  'militar',
#  'venezuela',
#  'demostracion_artilleria',
#  'rodar',
#  'realizarse',
#  'martes',
#  'nov16',
#  'instalación',
#  'circular',
#  'militar',
#  'desplegar',
#  'operativo',
#  'compania',
#  'estacion',
#  'servicio',
#  'armar',
#  'seguridad_ciudadana',
#  'preservar',
#  'soberania',
#  'ramosallup666',
#  'hoy',
#  'fanb_unificada',
#  'moral_concepto',
#  'trabajar',
#  'siempre',
#  'estara',
#  'nunca_mancharas',
#  'nombrar',
#  'reír',
#  'jajaja',
#  'dudes_manten',
#  'altitud',
#  'bolivar',
#  'fanb',
#  'amor',
#  'patrio',
#  'servicio',
#  'total',
#  'mas',
#  'necesitar',
#  'territorio',
#  'nacional',
#  '@prensafanb',
#  'hombre',
#  'mujer',
#  'llevando_alto',
#  'valor_liniamiento',
#  'soberano',
#  'revolucion',
#  'venezolano',
#  'conmemorar',
#  'ano',
#  'batallar',
#  'santa_ines',
#  'francisco_miranda',
#  'unir',
#  'patrio',
#  'legar',
#  'venezuela',
#  'comandar',
#  'aereo_#gnb',
#  'hombre',
#  'mujer',
#  'dar',
#  'útil',
#  'patrio',
#  'bolivar',
#  'obama',
#  'explicar',
#  'considerar',
#  'venezuela',
#  'amenazar',
#  'legar',
#  'sanchez',
#  'pedir',
#  'fin',
#  '‘',
#  'veto',
#  'cruzar',
#  '’',
#  'ciudadano',
#  'hispantv_noticias',
#  'morir',
#  'soldar',
#  'filipino',
#  'combatir',
#  'terrorista',
#  'afiliar',
#  'eiil',
#  'hispantv_noticias',
#  '30_082016',
#  'eeuu',
#  'turquia',
#  'pkk',
#  'participar',
#  'liberacion',
#  'mosul',
#  'turquia',
#  'arabia_saudi',
#  'plan',
#  'israeli',
#  'irak',
#  'iniciar',
#  'segundar',
#  'fase',
#  'liberacion',
#  'sur',
#  'zarif',
#  'arabia_saudi',
#  'exacerbar',
#  'amenazar',
#  'iran',
#  'arqueologos',
#  'mexicano',
#  'desenterrar',
#  'mamut',
#  'ano',
#  'informar',
#  'comision_europea',
#  'querer',
#  'centralizar',
#  'solicitudes_asilo',
#  'reitera_disposicion',
#  'enviar',
#  'fuerza',
#  'especial',
#  '’',
#  'sirio',
#  'corear',
#  'sur',
#  'cesar',
#  '\ufeff1',
#  'ministro',
#  'escandalo',
#  'politico',
#  'arsenal',
#  'nuclear',
#  'ruso',
#  'mas',
#  'avanzar',
#  'eeuu',
#  'valor',
#  'eeuu',
#  'gran',
#  'produccion',
#  'petrolero',
#  '‘',
#  'eeuu',
#  'mostrar',
#  'interes',
#  'resolver',
#  'conflicto',
#  'alepo',
#  '’',
#  'gnb_retiene',
#  'kgs',
#  'arroz',
#  'detener',
#  'ciudadano',
#  'merida',
#  'sondear',
#  'mayoria',
#  'britanicos',
#  'votaria',
#  'salir',
#  '‘',
#  'iran',
#  'planear',
#  'medir',
#  'incumplimiento',
#  'acordar',
#  'nuclear',
#  '’',
#  'protestar',
#  'agricultor',
#  'extender',
#  'oeste',
#  'francia',
#  'informar',
#  'riad',
#  'pagar',
#  'yemenies',
#  'proteger',
#  'frontero',
#  'saudí',
#  'egipto',
#  'negar',
#  'presenciar',
#  'militar',
#  'sirio',
#  'hispantv_noticias',
#  'salvador',
#  'entrar',
#  'alertar',
#  'nacional',
#  'amenazar',
#  'aedes_aegypti',
#  'isfahan',
#  'deslumbrante',
#  'capital',
#  'cultural',
#  'iran',
#  '‘',
#  'el_vendedor',
#  '’',
#  'farhadi',
#  'nominar',
#  'premio',
#  'globo',
#  'orar',
#  'estrella_globo',
#  'aerostatico',
#  'eeuu',
#  'tripulante',
#  'hacinamiento',
#  'gente',
#  'comprar',
#  'pan',
#  'fuerza',
#  'israelies',
#  'detener',
#  'palestino',
#  'incluir',
#  'adoles',
#  'cisjordania',
#  'informar',
#  'revelar',
#  'arabia_saudi',
#  'facilitar',
#  'huir',
#  'miembro',
#  'grupo',
#  'eeuu',
#  'eliminar',
#  'ayudar',
#  'paquistan',
#  'comprar',
#  'cazas_f16',
#  'sanders',
#  'pedir',
#  'revisar',
#  'sistema',
#  'electoral',
#  'obsoleto',
#  'eeuu',
#  'ejercitar',
#  'yemeni',
#  'lanzar',
#  'misil_balistico',
#  'campar',
#  'militar',
#  'saudi',
#  'argentino',
#  'escenario',
#  'mayor',
#  'marchar',
#  'macri',
#  'mesar',
#  'resultar',
#  'contrario',
#  'desear',
#  'nervioso',
#  'pondria',
#  'vida',
#  'riesgo',
#  'secundar',
#  'decision',
#  'ccg',
#  'declarar',
#  'grupo',
#  'terrorista',
#  'hezbola',
#  'bandas_criminales',
#  'aumentar',
#  'dato',
#  'violencia',
#  'colombia',
#  'elección',
#  'eeuu',
#  'punto',
#  'vestir',
#  'analista',
#  'chile',
#  'alertar',
#  'desastre',
#  'ganar',
#  'plebiscito',
#  'colombia',
#  'sindicato',
#  'protestar',
#  'londres',
#  'subir',
#  'tarifar',
#  'ferroviario',
#  'fuerzas_aereas',
#  'sirio',
#  'matar',
#  'cabecilla',
#  'rusia',
#  'chino',
#  'criticar',
#  'onu',
#  'informar',
#  '‘',
#  'politizar',
#  '’',
#  'ddhh',
#  'iran',
#  'gobernar',
#  'sirio',
#  'recibir',
#  'ciudadano',
#  'evacuar',
#  'riesgo',
#  'espionaje_masivo',
#  'ciudadano',
#  'paraguay',
#  'hispantv_noticias',
#  '30_092016',
#  'armar',
#  'insurgente',
#  'israel',
#  'elevar',
#  'necesitar',
#  'america',
#  'morir',
#  'mercenario',
#  'coalicion',
#  'ataque',
#  'ejercitar',
#  'yemeni',
#  'colombia',
#  'aprobar',
#  'via',
#  'rapida',
#  'aplicacion',
#  'acordar',
#  'paz',
#  'gnb',
#  'ministerio',
#  'salud_distribuyeron',
#  'lara',
#  'lider',
#  'civilizacion',
#  'islamica',
#  'cumplir',
#  'modelar',
#  'islamicoirani',
#  'desarrollar',
#  'gobernante',
#  'reunir',
#  'capital',
#  'salvadorena',
#  'onu',
#  'eiil',
#  'alqaeda',
#  'impedir',
#  'llegar',
#  'ayudar',
#  'humanitario',
#  'poblar',
#  'yemeni',
#  'legislador',
#  'brasileno',
#  'sugerir',
#  'pobre',
#  'comer',
#  '‘',
#  'dias',
#  '’',
#  'morir',
#  'sirio',
#  'terrorista',
#  'alqaeda',
#  'vincular',
#  'bin_laden',
#  'hispantv_noticias',
#  'video',
#  'policia',
#  'eeuu',
#  'matar',
#  '‘',
#  'enfermar',
#  'mental',
#  '’',
#  'disparo',
#  'ejercitar',
#  'irak',
#  'abatir',
#  'terrorista',
#  'eiil',
#  'oeste',
#  'video',
#  'mostrar',
#  'cuerpo',
#  'vida',
#  'integrante',
#  'daesh',
#  'mosul',
#  'activista',
#  'protestar',
#  'ciudad',
#  'mexico',
#  'ayotzinapa',
#  'hispantv_noticias',
#  'iran',
#  'rusia',
#  'negociar',
#  'produccion',
#  'conjunto',
#  'avión',
#  'sujoi',
#  'superjet',
#  'chino',
#  'protestar',
#  'restaurante',
#  'kfc',
#  'romper',
#  'iphones',
#  'injerencia',
#  'eeuu',
#  'ejercito_sirio',
#  'palmira',
#  'morir',
#  'civiles_incluidos',
#  'ninos',
#  'ataque',
#  'eeuu',
#  'irak',
#  'moral',
#  'permitir',
#  'derecho',
#  'volver',
#  'eeuu',
#  'advertir',
#  '‘',
#  'amenazar',
#  'creibles',
#  '’',
#  'atentar',
#  'estambul_antalya',
#  'aiea',
#  'advertir',
#  'corear',
#  'norte',
#  'reactivo',
#  'plantar',
#  'plutonio',
#  'senador',
#  'responsable',
#  'impeachment',
#  'rousseff',
#  'bajo_sospecha',
#  'cuartar',
#  'subir',
#  'combustible',
#  'empujar',
#  'inflacion',
#  'argentino',
#  'condenar',
#  'ano',
#  'carcel',
#  'poderoso',
#  'empresario',
#  'petrobras',
#  'esperanzar',
#  'vida',
#  'aumentar',
#  'ano',
#  'capturar',
#  'ciudadano',
#  'transporte_ilicito',
#  'drogar',
#  'apurar',
#  'hispantv_noticias',
#  'rajoy',
#  'fracasar',
#  'intentar',
#  'elegir',
#  'presidente',
#  'gobernar',
#  'morir',
#  'argentino',
#  'raúl',
#  'boli',
#  'lescano',
#  '‘',
#  'ejecucion',
#  'alnimr',
#  'igual',
#  'matar',
#  'pensamiento',
#  '’',
#  'comenzar',
#  'nuevo',
#  'astronomia_detectan',
#  'nuevamente',
#  'ondas_gravitacionales',
#  'predecir',
#  'irak',
#  'anticipar',
#  'expulsion',
#  'total',
#  'daesh',
#  'territorio',
#  'hispantv_noticias',
#  'hispantv_noticias',
#  '30_042016',
#  'sauron',
#  'nuevo',
#  'virus',
#  'hackeando',
#  'gobierno',
#  'ejercitos',
#  'secuestrar',
#  'hijo',
#  '‘',
#  'mexico',
#  'video',
#  'cazar',
#  'su35',
#  'ruso',
#  'alertar',
#  'patrullar',
#  'sirio',
#  'hamas',
#  '‘',
#  'judio',
#  '’',
#  'daesh',
#  'huye_mosul',
#  'sirio',
#  'avanzar',
#  'hallazgo',
#  'refutar',
#  'principal',
#  'teoria',
#  'poblo',
#  'america',
#  'infografia',
#  'gmas_distribuiran',
#  'medicinar',
#  'traves',
#  'clap',
#  'polemico_magnate',
#  'nuevo',
#  'presidente',
#  'eeuu',
#  'menos',
#  'muerto',
#  'atentados_suicidas',
#  'nigeria',
#  'congreso',
#  'otorgar',
#  'poder',
#  'presidente',
#  'dominicano',
#  'lluvia',
#  'video',
#  'politico',
#  'macrista',
#  'tirar',
#  'pisar',
#  'fingir',
#  'atacar',
#  'derecho',
#  'venezolano',
#  'llamar',
#  'censar',
#  'facilitar',
#  'revocatorio',
#  'madurar',
#  '‘',
#  'hezbola',
#  'capaz',
#  'luchar',
#  'israel',
#  'terrorista',
#  'sirio',
#  '’',
#  'millón',
#  'desplazar',
#  'guerra',
#  'catastrofes',
#  'arabia_saudi',
#  'regir',
#  'islam',
#  'suni',
#  'alterar',
#  'oriente_medio',
#  'acusar',
#  'acoso_sexual',
#  'renunciar',
#  'jefe',
#  'cadena',
#  'estadounidense',
#  'argentino',
#  'denunciar',
#  'crisis',
#  'agricola',
#  'donar',
#  'verdura',
#  'gente',
#  'holgar',
#  'italia',
#  'medidas_economicas',
#  'gobernar',
#  'atacar',
#  'misil_balistico',
#  'basar',
#  'saudi',
#  'asamblea',
#  'popular',
#  'venezuela',
#  'respaldar',
#  'presidente',
#  'nicolas',
#  'madurar',
#  'presidente',
#  'sirio',
#  'visitar',
#  'guerra',
#  'dia',
#  'madre',
#  'brutal_represion',
#  'policial',
#  'chile',
#  'estudiantes_secundarios',
#  'efecto',
#  'boomerang',
#  '‘',
#  'occidente',
#  'creer',
#  'daesh',
#  'volver',
#  '’',
#  'estadounidense',
#  'conmemorar',
#  'martin_luther',
#  'king',
#  'ejecutar',
#  'cabecilla',
#  'afgano',
#  'mosul',
#  'hispantv_noticias',
#  'hispantv_noticias',
#  'video',
#  'rocian',
#  'capriles',
#  'protestar',
#  'venezuela',
#  'menos',
#  'muerto',
#  'accidentar',
#  'mina_carbon',
#  'chino',
#  'pelicula',
#  'accion',
#  'mundo',
#  'real',
#  '‘',
#  'gran',
#  'miedo',
#  'posibilidad',
#  'trump',
#  'presidente',
#  '’',
#  '‘',
#  'interesar',
#  'europa',
#  'estan',
#  'hermanar',
#  'guerra',
#  'colapsar',
#  'hospital',
#  'devela',
#  'crisis',
#  'salud',
#  'público',
#  'chile',
#  'dejar',
#  'efecto',
#  'funcionarios_brindaran',
#  'seguridad',
#  'valle',
#  'tuy',
#  'miranda',
#  'rusia',
#  'llamar',
#  'ayudar',
#  'sirio',
#  'cercar',
#  'terrorista',
#  'crecer',
#  'desconfianza',
#  'ttip',
#  'europa',
#  'ramosallup666',
#  'ramosallup666_ofende',
#  'fanb',
#  'exigir',
#  'politicos',
#  'mayor',
#  'altura',
#  'asi',
#  'dias',
#  'debemos_sentirnos',
#  'profundamente_orgullosos',
#  'video',
#  'dios',
#  'bolivar',
#  'chavez',
#  'navidad',
#  'paz',
#  'union',
#  'fraternidad',
#  'perfecto',
#  'union_civicomilitar',
#  'general',
#  'venezolano',
#  'precursor_emancipacion',
#  'americano',
#  'imperio',
#  'espanol',
#  'caprichosa_búscate',
#  'machota',
#  'loquero',
#  'hoy',
#  'apoyar',
#  'fanb',
#  'twitter_usemos',
#  'celebrar',
#  'hoy',
#  'dia',
#  '@aviacionfanb',
#  'nooooooooo_demonio',
#  'ramosallup666',
#  'acto',
#  'ascenso',
#  'condecoracion',
#  'personal',
#  'militar',
#  'premiar',
#  'merito',
#  'gradar',
#  'inmediato',
#  'superior',
#  'hijo',
#  'patrio',
#  'social',
#  'ramosallup666_ofende',
#  'fanb',
#  'exigir',
#  'politicos',
#  'mayor',
#  'altura',
#  'expedicion',
#  'cayos_finales',
#  'vzla',
#  'imperio',
#  'referencia_historica',
#  'inmortal',
#  'luchar',
#  'independencia',
#  'libertar',
#  'manifiesto',
#  'militar',
#  'cupula_podrida',
#  'corrupto',
#  'urgente',
#  'ramos_allup',
#  'pronuncia_peligrosamente',
#  'vamos_camaradas',
#  'etiquetar',
#  'procer',
#  'tabaco',
#  'matar',
#  'jovenes',
#  'hispano',
#  'obama',
#  'politica',
#  'aislamiento',
#  'guerra_fria',
#  'funcionar',
#  'eeuu',
#  'destituir',
#  'kyle',
#  'moses',
#  'arrestar',
#  'marine',
#  'fuerza',
#  'iranies',
#  'protestar',
#  'michel_temer',
#  'inauguracion',
#  'juegos_olimpicos',
#  'visitar',
#  'iran',
#  'abrir',
#  'nuevo',
#  'etapa',
#  'vinculos',
#  'teheranpekin',
#  'fuerza',
#  'israelies_matan',
#  'tiro',
#  'zarif',
#  'iran',
#  'oponer',
#  'balcanizacion',
#  'sirio',
#  'irak',
#  'rusia',
#  'criticar',
#  'afirmación',
#  'arrogante',
#  'mogherini',
#  'crimea',
#  'millón',
#  'gadafi',
#  'llegar',
#  'millonario',
#  'saudi',
#  'senador',
#  'eeuu',
#  'vez',
#  'enfrentar',
#  'elección',
#  'candidato',
#  'intensamente',
#  'oidos',
#  'aviacion',
#  'iraqui',
#  'negar',
#  'atacar',
#  'civil',
#  'frontero',
#  'sirio',
#  'hezbola',
#  'advertir',
#  'wahabismo',
#  'mas',
#  'pernicioso',
#  'israel',
#  'millón',
#  'desplazar',
#  'sirio',
#  'regresar',
#  'casar',
#  '”',
#  'chavismo',
#  'denunciar',
#  'acto',
#  '‘',
#  'nulo',
#  '’',
#  '‘',
#  'ilegal',
#  '’',
#  'oposicion',
#  'foto',
#  'conocer',
#  'poblar',
#  'cabellar',
#  'mas',
#  'largar',
#  'mundo',
#  'descubrir',
#  'primero',
#  'vez',
#  'manipular',
#  'cerebro_humano',
#  'iran',
#  'exigir',
#  'fin',
#  'agresion',
#  '‘',
#  'sinsentido',
#  '’',
#  'yemen',
#  'designación',
#  'autoridad',
#  ...]

# %% [markdown]
# ### Finally remove misc characters

# %%
def remove_misc(tweets):
    misc_chars = set(['#','🇻','🇪','jajajajaja','”','‘','’', 'rt', 'jajaja'])
    
    return [[token for token in tweet 
                     if token not in misc_chars] 
                        for tweet in tweets]

# %%
data_lem_final = remove_misc(data_lemmatized)

# %% [markdown]
# ## Create Dictionary and Corpus

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lem_final)

# Create Corpus
tweets = data_lem_final

# Term Document Frequency
corpus = [id2word.doc2bow(tweet) for tweet in tweets]

# View
#print(corpus[24])

# %% [markdown]
# ## Build Preliminary Topic Model

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=50, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(46,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"rt" + 0.000*"mundo" + 0.000*"deporte" '
#   '+ 0.000*"video" + 0.000*"eeuu" + 0.000*"android" + 0.000*"nuevo" + '
#   '0.000*"venezuela"'),
#  (9,
#   '0.000*"noticiar" + 0.000*"rt" + 0.000*"#" + 0.000*"último" + 0.000*"mundo" '
#   '+ 0.000*"vzla" + 0.000*"deporte" + 0.000*"android" + 0.000*"venezuela" + '
#   '0.000*"nuevo"'),
#  (44,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"último" + 0.000*"video" + '
#   '0.000*"android" + 0.000*"mas" + 0.000*"rt" + 0.000*"news" + '
#   '0.000*"venezuela" + 0.000*"eeuu"'),
#  (15,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"último" + 0.000*"rt" + '
#   '0.000*"deporte" + 0.000*"news" + 0.000*"mundo" + 0.000*"video" + '
#   '0.000*"eeuu" + 0.000*"venezuela"'),
#  (24,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"news" + 0.000*"rt" + 0.000*"android" '
#   '+ 0.000*"último" + 0.000*"momento" + 0.000*"venezuela" + 0.000*"mas" + '
#   '0.000*"eeuu"'),
#  (39,
#   '0.000*"noticiar" + 0.000*"news" + 0.000*"#" + 0.000*"último" + '
#   '0.000*"deporte" + 0.000*"technology" + 0.000*"eeuu" + 0.000*"nuevo" + '
#   '0.000*"ahora" + 0.000*"hora"'),
#  (40,
#   '0.000*"#" + 0.000*"noticiar" + 0.000*"venezuela" + 0.000*"nuevo" + '
#   '0.000*"madurar" + 0.000*"mundo" + 0.000*"video" + 0.000*"mas" + 0.000*"ano" '
#   '+ 0.000*"venezolano"'),
#  (20,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"news" + 0.000*"rt" + 0.000*"android" '
#   '+ 0.000*"venezuela" + 0.000*"último" + 0.000*"mas" + 0.000*"mundo" + '
#   '0.000*"eeuu"'),
#  (29,
#   '0.000*"noticiar" + 0.000*"rt" + 0.000*"vzla" + 0.000*"mundo" + 0.000*"#" + '
#   '0.000*"venezuela" + 0.000*"eeuu" + 0.000*"presidente" + 0.000*"nuevo" + '
#   '0.000*"news"'),
#  (11,
#   '0.000*"noticiar" + 0.000*"#" + 0.000*"venezuela" + 0.000*"eeuu" + '
#   '0.000*"ahora" + 0.000*"mas" + 0.000*"nuevo" + 0.000*"actualidadrt" + '
#   '0.000*"foto" + 0.000*"rt"'),
#  (25,
#   '0.022*"rusia" + 0.015*"ruso" + 0.015*"eeuu" + 0.014*"sirio" + 0.008*"ojo" + '
#   '0.006*"mas" + 0.006*"nuevo" + 0.006*"militar" + 0.005*"turquia" + '
#   '0.004*"gobernar"'),
#  (13,
#   '0.012*"venezuela" + 0.010*"venezolano" + 0.010*"foto" + 0.007*"presidente" '
#   '+ 0.007*"madurar" + 0.007*"nacional" + 0.007*"ano" + 0.006*"nuevo" + '
#   '0.006*"gobernar" + 0.006*"mas"'),
#  (19,
#   '0.067*"via" + 0.055*"@nicolasmaduro" + 0.030*"patrio" + 0.026*"revolucion" '
#   '+ 0.026*"poblar" + 0.019*"pdte" + 0.016*"movimiento_teatral" + '
#   '0.013*"chavez" + 0.013*"juventud" + 0.011*"seguir"'),
#  (48,
#   '0.020*"madurar" + 0.017*"venezuela" + 0.009*"venezolano" + 0.007*"gobernar" '
#   '+ 0.006*"video" + 0.006*"mas" + 0.006*"foto" + 0.006*"pais" + 0.006*"nuevo" '
#   '+ 0.005*"revocatorio"'),
#  (7,
#   '0.015*"via" + 0.010*"venezuela" + 0.008*"nuevo" + 0.008*"presidente" + '
#   '0.008*"gobernar" + 0.006*"venezolano" + 0.006*"colombia" + 0.006*"mas" + '
#   '0.006*"paz" + 0.005*"ano"'),
#  (12,
#   '0.082*"trump" + 0.051*"video" + 0.019*"obama" + 0.015*"’s" + 0.013*"’" + '
#   '0.012*"‘" + 0.011*"hillary" + 0.009*"donald" + 0.007*"says" + '
#   '0.005*"election"'),
#  (18,
#   '0.027*"leer" + 0.020*"android" + 0.020*"nuevo" + 0.017*"tecnologia" + '
#   '0.016*"videojuego" + 0.015*"mas" + 0.011*"google" + 0.007*"llegar" + '
#   '0.005*"mejorar" + 0.005*"asi"'),
#  (27,
#   '0.016*"venezuela" + 0.012*"presidente" + 0.012*"madurar" + 0.011*"poblar" + '
#   '0.007*"nacional" + 0.007*"opinion" + 0.006*"venezolano" + 0.006*"ano" + '
#   '0.006*"caracas" + 0.006*"gobernar"'),
#  (28,
#   '0.075*"chiste" + 0.015*"mas" + 0.014*"querer" + 0.013*"hacer" + 0.009*"ver" '
#   '+ 0.009*"bueno" + 0.009*"decir" + 0.009*"asi" + 0.007*"solo" + 0.006*"dia"'),
#  (37,
#   '0.020*"fanb" + 0.015*"poblar" + 0.014*"hoy" + 0.014*"patrio" + '
#   '0.012*"militar" + 0.011*"venezuela" + 0.010*"mas" + 0.010*"venezolano" + '
#   '0.009*"dia" + 0.009*"legionfanb"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lem_final, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis

# %% [markdown]
# ## Optimal Number of Topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
        #model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %% [markdown]
# ### Breadth Search

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lem_final, start=2, limit=150, step=25)
# Show graph
limit=150; start=2; step=25;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %% [markdown]
# ### Depth Search

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lem_final, start=2, limit=50, step=5)
# Show graph
limit=50; start=2; step=5;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %% [markdown]
# ### Optimal Search

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lem_final, start=2, limit=12, step=2)

# Show graph
limit=12; start=2; step=2;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %% [markdown]
# ### Best LDA Model

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=###, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# View Topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

# Model Perplexity and Coherence
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lem_final, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
pyLDAvis.display(vis)
